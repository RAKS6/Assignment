# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ** RAHUL KUMBAR**
# I want to be a data scientist

# %% [markdown]
# *I want to be a data scientist just because of advancement of this field and the vast area of emolpyeement and the craze and education of this field*

# %% [markdown]
# ### we are adding two numbers here and getting output for the same number

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1.rahul kumbar
# 2.girish v
# 3.venkatesh
#
# - pushpraj
# - habibullah
# - shravana t
#
# ![ibm.jpg](attachment:ibm.jpg)
